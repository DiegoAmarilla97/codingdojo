# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.head(10)
# Out:
#            id                       title                        genres  \
# 0   tt0903747                Breaking Bad        Crime, Drama, Thriller
# 1   tt5491994             Planet Earth II                   Documentary
# 2   tt0185906            Band of Brothers           Drama, History, War
# 3   tt0795176                Planet Earth           Documentary, Family
# 4   tt5152226                Tree of Life                         Drama
# 5   tt7366338                   Chernobyl      Drama, History, Thriller
# 6   tt0306414                    The Wire        Crime, Drama, Thriller
# 7   tt0417299  Avatar: The Last Airbender  Action, Adventure, Animation
# 8  tt30263074           Sapne Vs Everyone                         Drama
# 9   tt6769208              Blue Planet II                   Documentary
#
#    averageRating  numVotes  releaseYear
# 0            9.5   2220756         2008
# 1            9.5    161283         2016
# 2            9.4    542837         2001
# ...

# %%
#Muestra las últimas 5 filas del DataFrame.
df.tail()
# Out:
#              id            title                        genres  averageRating  \
# 995   tt8910922  Solar Opposites  Adventure, Animation, Comedy            7.9
# 996   tt5368542     The Exorcist        Drama, Horror, Mystery            7.9
# 997  tt11379026           Ghosts               Comedy, Fantasy            7.9
# 998  tt14824792              Ted                        Comedy            7.9
# 999   tt2262532      The Fosters                Drama, Romance            7.9
#
#      numVotes  releaseYear
# 995     32325         2020
# 996     32302         2016
# 997     32160         2021
# 998     31431         2024
# 999     31280         2013

# %%
#Utiliza el método info() para obtener información general sobre el DataFrame, incluyendo el número de entradas, nombres de las columnas, tipos de datos y memoria utilizada.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   object
#  1   title          1000 non-null   object
#  2   genres         1000 non-null   object
#  3   averageRating  1000 non-null   float64
#  4   numVotes       1000 non-null   int64
#  5   releaseYear    1000 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
#Genera estadísticas descriptivas del DataFrame utilizando el método describe().
df.describe()
# Out:
#        averageRating      numVotes  releaseYear
# count    1000.000000  1.000000e+03  1000.000000
# mean        8.368200  9.186382e+04  2010.222000
# std         0.321889  1.731002e+05    12.339975
# min         7.900000  1.000800e+04  1951.000000
# 25%         8.100000  1.787075e+04  2005.000000
# 50%         8.300000  3.443650e+04  2014.000000
# 75%         8.600000  9.034800e+04  2019.000000
# max         9.500000  2.355676e+06  2024.000000

# %%
#Crea nuevas columnas basadas en operaciones con las columnas existentes (por ejemplo, calcular ingresos a partir de ventas y precios).
meanVotes = df['numVotes'].mean()
df['ponVotes'] = df['averageRating']*df['numVotes']/meanVotes 

print(df.sort_values('ponVotes',ascending=False).head())
# Out:
#             id            title                    genres  averageRating  \
# 13   tt0944947  Game of Thrones  Action, Adventure, Drama            9.2
# 0    tt0903747     Breaking Bad    Crime, Drama, Thriller            9.5
# 117  tt4574334  Stranger Things    Drama, Fantasy, Horror            8.7
# 64   tt0108778          Friends           Comedy, Romance            8.9
# 23   tt1475582         Sherlock     Crime, Drama, Mystery            9.1
#
#      numVotes  releaseYear    ponVotes
# 13    2355676         2011  235.916800
# 0     2220756         2008  229.657131
# 117   1384590         2016  131.128148
# 64    1112540         1994  107.785695
# 23    1021067         2010  101.146560

# %%
crime_shows = df[df['genres'].str.contains('Crime')]
crime_shows
# Out:
#              id                               title                   genres  \
# 0     tt0903747                        Breaking Bad   Crime, Drama, Thriller
# 6     tt0306414                            The Wire   Crime, Drama, Thriller
# 14    tt0141842                        The Sopranos             Crime, Drama
# 16   tt12392504  Scam 1992: The Harshad Mehta Story  Biography, Crime, Drama
# 23    tt1475582                            Sherlock    Crime, Drama, Mystery
# ..          ...                                 ...                      ...
# 976   tt1582457                         The Borgias    Crime, Drama, History
# 977   tt2654580                        Almost Human     Action, Crime, Drama
# 984   tt0118401                    Midsomer Murders    Crime, Drama, Mystery
# 992   tt1255913                      Bored to Death     Comedy, Crime, Drama
# 994   tt1958961                          Lilyhammer     Comedy, Crime, Drama
#
# ...

# %%
# Split genres and explode the DataFrame to count occurrences
genre_counts = df['genres'].str.split(', ').explode().value_counts()

print(genre_counts)
# Out:
# genres
# Drama          611
# Comedy         383
# Crime          244
# Action         236
# Adventure      183
# Animation      182
# Mystery        111
# Romance         86
# Thriller        72
# Fantasy         58
# History         47
# Documentary     46
# Biography       39
# Family          36
# Horror          30
# Sci-Fi          29
# Music           19
# Sport           17
# War             14
# Talk-Show       13
# Reality-TV       9
# Game-Show        6
# Musical          6
# Western          6
# Short            4
# News             4
# Name: count, dtype: int64
