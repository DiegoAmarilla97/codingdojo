# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Diego\Downloads\Datos Publicos\Subsidios.csv', sep=';')

df.head()
# Out:
#    Nivel  Código entidad                      Entidad  Clase programa  \
# 0     12               1  PRESIDENCIA DE LA REPÚBLICA               2
# 1     12               1  PRESIDENCIA DE LA REPÚBLICA               2
# 2     12               1  PRESIDENCIA DE LA REPÚBLICA               2
# 3     12               1  PRESIDENCIA DE LA REPÚBLICA               2
# 4     12               1  PRESIDENCIA DE LA REPÚBLICA               2
#
#    Código programa                              Nombre programa  \
# 0                1  EMERGENCIA SANITARIA ANTE PANDEMIA COVID-19
# 1                1  EMERGENCIA SANITARIA ANTE PANDEMIA COVID-19
# 2                1  EMERGENCIA SANITARIA ANTE PANDEMIA COVID-19
# 3                1  EMERGENCIA SANITARIA ANTE PANDEMIA COVID-19
# 4                1  EMERGENCIA SANITARIA ANTE PANDEMIA COVID-19
#
#    Código proyecto actividad                    Nombre actividad proyecto  \
# 0                          1  SUBSIDIO PARA BONOS ALIMENTICIOS A FAMILIAS
# ...

# %%
df.nunique()
# Out:
# Nivel                             1
# Código entidad                    1
# Entidad                           1
# Clase programa                    1
# Código programa                   1
# Nombre programa              259117
# Código proyecto actividad         1
# Nombre actividad proyecto         1
# Tipo subsidio programa            1
# Número documento             269006
# Nombre beneficiario          265816
# Id departamento                  15
# Nombre departamento              15
# Id municipio                     31
# Nombre municipio                246
# Característica subsidio           1
# Nombre subsidio                   1
# Valor subsidio                    1
# Cantidad subsidio                 1
# Fecha cargue archivo              1
# Fuente datos                      1
# dtype: int64

# %%
df['Valor subsidio'].sum()
# Out:
# np.int64(134503000000)
